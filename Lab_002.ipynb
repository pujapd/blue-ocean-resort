# %% [markdown]
# <a href="https://colab.research.google.com/github/pujapd/blue-ocean-resort/blob/main/Lab_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ==========================================
# Image Resizing using OpenCV
# ==========================================

import cv2
import matplotlib.pyplot as plt
from google.colab import files

# Upload image
uploaded = files.upload()

# Read image
image_path = list(uploaded.keys())[0]
image = cv2.imread(image_path)

# Convert BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Original image size
print("Original Shape:", image.shape)

# Resize Image (Width = 600, Height = 400)
resized = cv2.resize(image, (600, 400))

print("Resized Shape:", resized.shape)

# Display Images
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(image)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(resized)
plt.title("Resized Image")
plt.axis("off")

plt.show()
# Out:
#      <input type="file" id="files-c4b9f20e-b971-4f5c-846f-2c4e8198ed95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4b9f20e-b971-4f5c-846f-2c4e8198ed95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ==========================================
# Image Cropping using OpenCV (Automatic Center Crop)
# ==========================================

import cv2
import matplotlib.pyplot as plt
from google.colab import files

# ------------------------------------------
# Upload Image
# ------------------------------------------
uploaded = files.upload()

# Get uploaded file name
image_path = list(uploaded.keys())[0]

# ------------------------------------------
# Read Image
# ------------------------------------------
image = cv2.imread(image_path)

# Convert BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# ------------------------------------------
# Get Image Size
# ------------------------------------------
height, width = image.shape[:2]

print("Original Image Shape :", image.shape)
print("Height :", height)
print("Width  :", width)

# ------------------------------------------
# Crop the Center 50% of the Image
# ------------------------------------------

crop_width = width // 2
crop_height = height // 2

# Starting coordinates
start_x = (width - crop_width) // 2
start_y = (height - crop_height) // 2

# Ending coordinates
end_x = start_x + crop_width
end_y = start_y + crop_height

# Crop Image
cropped = image[start_y:end_y, start_x:end_x]

print("\nCropping Coordinates")
print(f"Start Point : ({start_x}, {start_y})")
print(f"End Point   : ({end_x}, {end_y})")

print("\nCropped Image Shape :", cropped.shape)

# ------------------------------------------
# Display Images
# ------------------------------------------
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(image)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(cropped)
plt.title("Cropped Image")
plt.axis("off")

plt.show()
# Out:
#      <input type="file" id="files-901ba9c5-0ee7-4d4b-9fcc-5b820c7615a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-901ba9c5-0ee7-4d4b-9fcc-5b820c7615a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ==========================================
# Image Rotation using OpenCV
# ==========================================

import cv2
import matplotlib.pyplot as plt
from google.colab import files

# Upload image
uploaded = files.upload()

# Read image
image_path = list(uploaded.keys())[0]
image = cv2.imread(image_path)

# Convert BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

height, width = image.shape[:2]

# Center of Image
center = (width // 2, height // 2)

# Rotation Matrix
rotation_matrix = cv2.getRotationMatrix2D(center, 45, 1)

# Rotate Image
rotated = cv2.warpAffine(image,
                         rotation_matrix,
                         (width, height))

# Display Images
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(image)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(rotated)
plt.title("Rotated Image (45°)")
plt.axis("off")

plt.show()
# Out:
#      <input type="file" id="files-37fce1ec-062a-4598-a3c1-9de1255ea7e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37fce1ec-062a-4598-a3c1-9de1255ea7e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
